# %%
import requests
import json 
from pprint import pprint 
import seaborn as sns
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib

# %%
url = "https://archive-api.open-meteo.com/v1/archive"
params = {
	"latitude": 52.52,
	"longitude": 13.41,
	"start_date": "2000-01-01",
	"end_date": "2026-02-06",
	"daily": ["weather_code", "temperature_2m_mean", "precipitation_sum", "daylight_duration", "sunshine_duration", "apparent_temperature_mean", "sunrise", "sunset", "rain_sum", "snowfall_sum", "precipitation_hours", "wind_direction_10m_dominant", "relative_humidity_2m_mean", "pressure_msl_mean", "dew_point_2m_mean", "cloud_cover_mean", "surface_pressure_mean", "wind_gusts_10m_mean", "wind_speed_10m_mean"],
	"timezone": "America/Chicago",
}
response = requests.get(url, params=params)

print(response.status_code)
print(response.headers.get("Content-Type"))
print(response.text[:200])  

data = response.json()
# Out:
# 200
# application/json; charset=utf-8
# {"latitude":52.54833,"longitude":13.407822,"generationtime_ms":100.13675689697266,"utc_offset_seconds":-21600,"timezone":"America/Chicago","timezone_abbreviation":"GMT-6","elevation":38.0,"daily_units

# %%
for r in response.json():
    print(r)
# Out:
# latitude
# longitude
# generationtime_ms
# utc_offset_seconds
# timezone
# timezone_abbreviation
# elevation
# daily_units
# daily

# %%
weather_df = pd.DataFrame(response.json()['daily'])
weather_df.head()
# Out:
#          time  weather_code  temperature_2m_mean  precipitation_sum  \
# 0  2000-01-01            71                  1.8                2.5
# 1  2000-01-02             3                  3.6                0.0
# 2  2000-01-03            51                  5.7                0.2
# 3  2000-01-04            55                  5.5                4.7
# 4  2000-01-05             3                  1.6                0.0
#
#    daylight_duration  sunshine_duration  apparent_temperature_mean  \
# 0           27884.61               0.00                       -1.6
# 1           27958.83               0.00                       -0.2
# 2           28039.85               0.00                        1.4
# 3           28127.45            2097.16                        1.6
# 4           28221.39           21833.25                       -2.7
#
#             sunrise            sunset  rain_sum  snowfall_sum  \
# 0  2000-01-01T01:17  2000-01-01T09:01       1.9          0.42
# 1  2000-01-02T01:17  2000-01-02T09:02       0.0          0.00
# 2  2000-01-03T01:17  2000-01-03T09:03       0.2          0.00
# 3  2000-01-04T01:16  2000-01-04T09:05       4.7          0.00
# 4  2000-01-05T01:16  2000-01-05T09:06       0.0          0.00
#
#    precipitation_hours  wind_direction_10m_dominant  \
# 0                  9.0                          235
# 1                  0.0                          248
# 2                  2.0                          235
# 3                 11.0                          236
# 4                  0.0                          246
#
#    relative_humidity_2m_mean  pressure_msl_mean  dew_point_2m_mean  \
# 0                         96             1022.6                1.2
# 1                         93             1026.2                2.5
# 2                         84             1019.9                3.1
# 3                         90             1014.5                4.0
# 4                         84             1020.8               -0.8
#
#    cloud_cover_mean  surface_pressure_mean  wind_gusts_10m_mean  \
# 0               100                 1017.8                 19.4
# 1               100                 1021.4                 28.3
# 2               100                 1015.1                 35.3
# 3                94                 1009.8                 33.1
# 4                52                 1016.0                 28.6
#
#    wind_speed_10m_mean
# 0                 10.3
# 1                 14.7
# 2                 18.7
# 3                 17.1
# 4                 14.3

# %%
weather_df.shape
# Out:
# (9534, 20)

# %%
weather_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9534 entries, 0 to 9533
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time                         9534 non-null   str
#  1   weather_code                 9534 non-null   int64
#  2   temperature_2m_mean          9534 non-null   float64
#  3   precipitation_sum            9534 non-null   float64
#  4   daylight_duration            9534 non-null   float64
#  5   sunshine_duration            9534 non-null   float64
#  6   apparent_temperature_mean    9534 non-null   float64
#  7   sunrise                      9534 non-null   str
#  8   sunset                       9534 non-null   str
#  9   rain_sum                     9534 non-null   float64
#  10  snowfall_sum                 9534 non-null   float64
#  11  precipitation_hours          9534 non-null   float64
#  12  wind_direction_10m_dominant  9534 non-null   int64
#  13  relative_humidity_2m_mean    9534 non-null   int64
#  14  pressure_msl_mean            9534 non-null   float64
#  15  dew_point_2m_mean            9534 non-null   float64
#  16  cloud_cover_mean             9534 non-null   int64
#  17  surface_pressure_mean        9534 non-null   float64
#  18  wind_gusts_10m_mean          9534 non-null   float64
#  19  wind_speed_10m_mean          9534 non-null   float64
# dtypes: float64(13), int64(4), str(3)
# memory usage: 1.8 MB

# %%
weather_df.describe()
# Out:
#        weather_code  temperature_2m_mean  precipitation_sum  \
# count   9534.000000          9534.000000        9534.000000
# mean      33.973883            10.279411           1.692385
# std       27.523391             7.822545           3.536433
# min        0.000000           -18.000000           0.000000
# 25%        3.000000             4.300000           0.000000
# 50%       51.000000            10.300000           0.200000
# 75%       53.000000            16.600000           1.900000
# max       75.000000            30.800000         120.700000
#
#        daylight_duration  sunshine_duration  apparent_temperature_mean  \
# count        9534.000000        9534.000000                9534.000000
# mean        44156.964077       26532.065024                   7.666656
# std         11269.265851       17169.424800                   9.315783
# min         27513.480000           0.000000                 -23.200000
# 25%         33325.370000       11652.102500                   0.200000
# 50%         44233.450000       27572.315000                   7.400000
# 75%         54983.462500       41791.782500                  15.200000
# max         60626.600000       55590.410000                  31.200000
#
#           rain_sum  snowfall_sum  precipitation_hours  \
# count  9534.000000   9534.000000          9534.000000
# mean      1.576159      0.087790             3.584749
# std       3.478926      0.465433             4.786746
# min       0.000000      0.000000             0.000000
# 25%       0.000000      0.000000             0.000000
# 50%       0.100000      0.000000             1.000000
# 75%       1.700000      0.000000             6.000000
# max     120.700000      9.800000            24.000000
#
#        wind_direction_10m_dominant  relative_humidity_2m_mean  \
# count                  9534.000000                9534.000000
# mean                    199.123872                  75.795993
# std                      90.975753                  12.498888
# min                       0.000000                  29.000000
# 25%                     121.000000                  67.000000
# 50%                     223.000000                  77.000000
# 75%                     268.000000                  86.000000
# max                     360.000000                  99.000000
#
#        pressure_msl_mean  dew_point_2m_mean  cloud_cover_mean  \
# count        9534.000000        9534.000000       9534.000000
# mean         1015.503377           5.684854         66.944619
# std             9.044767           6.441319         27.359503
# min           974.100000         -22.400000          0.000000
# 25%          1010.000000           1.200000         49.000000
# 50%          1015.700000           6.000000         73.000000
# 75%          1021.100000          10.700000         90.000000
# max          1047.400000          21.200000        100.000000
#
#        surface_pressure_mean  wind_gusts_10m_mean  wind_speed_10m_mean
# count            9534.000000          9534.000000          9534.000000
# mean             1010.861684            25.741903            12.816530
# std                 8.990947             9.444250             5.026514
# min               969.500000             5.100000             2.100000
# 25%              1005.400000            18.900000             9.100000
# 50%              1011.100000            24.000000            12.000000
# 75%              1016.500000            30.900000            15.600000
# max              1042.100000            73.500000            36.100000

# %%
weather_df.isna().head()
# Out:
#     time  weather_code  temperature_2m_mean  precipitation_sum  \
# 0  False         False                False              False
# 1  False         False                False              False
# 2  False         False                False              False
# 3  False         False                False              False
# 4  False         False                False              False
#
#    daylight_duration  sunshine_duration  apparent_temperature_mean  sunrise  \
# 0              False              False                      False    False
# 1              False              False                      False    False
# 2              False              False                      False    False
# 3              False              False                      False    False
# 4              False              False                      False    False
#
#    sunset  rain_sum  snowfall_sum  precipitation_hours  \
# 0   False     False         False                False
# 1   False     False         False                False
# 2   False     False         False                False
# 3   False     False         False                False
# 4   False     False         False                False
#
#    wind_direction_10m_dominant  relative_humidity_2m_mean  pressure_msl_mean  \
# 0                        False                      False              False
# 1                        False                      False              False
# 2                        False                      False              False
# 3                        False                      False              False
# 4                        False                      False              False
#
#    dew_point_2m_mean  cloud_cover_mean  surface_pressure_mean  \
# 0              False             False                  False
# 1              False             False                  False
# 2              False             False                  False
# 3              False             False                  False
# 4              False             False                  False
#
#    wind_gusts_10m_mean  wind_speed_10m_mean
# 0                False                False
# 1                False                False
# 2                False                False
# 3                False                False
# 4                False                False

# %%
weather_df.isna().sum()
# Out:
# time                           0
# weather_code                   0
# temperature_2m_mean            0
# precipitation_sum              0
# daylight_duration              0
# sunshine_duration              0
# apparent_temperature_mean      0
# sunrise                        0
# sunset                         0
# rain_sum                       0
# snowfall_sum                   0
# precipitation_hours            0
# wind_direction_10m_dominant    0
# relative_humidity_2m_mean      0
# pressure_msl_mean              0
# dew_point_2m_mean              0
# cloud_cover_mean               0
# surface_pressure_mean          0
# wind_gusts_10m_mean            0
# wind_speed_10m_mean            0
# dtype: int64

# %%
weather_df["time"] = pd.to_datetime(weather_df["time"])
weather_df["year"] = weather_df["time"].dt.year
weather_df["month"] = weather_df["time"].dt.month
weather_df["day"] = weather_df["time"].dt.day

weather_df.head()
# Out:
#         time  weather_code  temperature_2m_mean  precipitation_sum  \
# 0 2000-01-01            71                  1.8                2.5
# 1 2000-01-02             3                  3.6                0.0
# 2 2000-01-03            51                  5.7                0.2
# 3 2000-01-04            55                  5.5                4.7
# 4 2000-01-05             3                  1.6                0.0
#
#    daylight_duration  sunshine_duration  apparent_temperature_mean  \
# 0           27884.61               0.00                       -1.6
# 1           27958.83               0.00                       -0.2
# 2           28039.85               0.00                        1.4
# 3           28127.45            2097.16                        1.6
# 4           28221.39           21833.25                       -2.7
#
#             sunrise            sunset  rain_sum  ...  \
# 0  2000-01-01T01:17  2000-01-01T09:01       1.9  ...
# 1  2000-01-02T01:17  2000-01-02T09:02       0.0  ...
# 2  2000-01-03T01:17  2000-01-03T09:03       0.2  ...
# 3  2000-01-04T01:16  2000-01-04T09:05       4.7  ...
# 4  2000-01-05T01:16  2000-01-05T09:06       0.0  ...
#
#    relative_humidity_2m_mean  pressure_msl_mean  dew_point_2m_mean  \
# 0                         96             1022.6                1.2
# 1                         93             1026.2                2.5
# 2                         84             1019.9                3.1
# 3                         90             1014.5                4.0
# 4                         84             1020.8               -0.8
#
#    cloud_cover_mean  surface_pressure_mean  wind_gusts_10m_mean  \
# 0               100                 1017.8                 19.4
# 1               100                 1021.4                 28.3
# 2               100                 1015.1                 35.3
# 3                94                 1009.8                 33.1
# 4                52                 1016.0                 28.6
#
#    wind_speed_10m_mean  year  month  day
# 0                 10.3  2000      1    1
# 1                 14.7  2000      1    2
# 2                 18.7  2000      1    3
# 3                 17.1  2000      1    4
# 4                 14.3  2000      1    5
#
# [5 rows x 23 columns]

# %%
weather_df.groupby('month').temperature_2m_mean.agg(['mean','std', 'median', 'count'])
# Out:
#             mean       std  median  count
# month
# 1       0.813978  4.628783    0.90    837
# 2       1.857085  4.267200    1.80    741
# 3       4.712283  3.894144    5.10    806
# 4       9.620000  3.994625    9.60    780
# 5      14.419231  3.598432   14.35    806
# 6      18.288462  3.574147   18.10    780
# 7      19.812655  3.320576   19.40    806
# 8      19.660794  3.208192   19.30    806
# 9      15.482821  3.274433   15.30    780
# 10     10.609057  3.350962   10.70    806
# 11      5.639103  3.538876    5.80    780
# 12      2.377543  4.080160    2.40    806
